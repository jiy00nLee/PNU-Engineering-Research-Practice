# %% [markdown]
# ## 실습 진행

# %% [markdown]
# ####  데이터 정형화하기
# - kddcup.data.gz, kddcup.data_10_percednt.gz
# - info(), describe(), corr() 함수들을 이용한 데이터 파악
# - 데이터 정형화 수행
#     - 범주형
#     - 정형화
#     - 표준화

# %%
import os
import pandas as pd
csv_path = os.path.join("./datasets/kddcupdata/kddcup.data_10_percent_corrected")

# %%
housing = pd.read_csv(csv_path)

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494020 entries, 0 to 494019
# Data columns (total 42 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   0        494020 non-null  int64
#  1   tcp      494020 non-null  object
#  2   http     494020 non-null  object
#  3   SF       494020 non-null  object
#  4   181      494020 non-null  int64
#  5   5450     494020 non-null  int64
#  6   0.1      494020 non-null  int64
#  7   0.2      494020 non-null  int64
#  8   0.3      494020 non-null  int64
#  9   0.4      494020 non-null  int64
#  10  0.5      494020 non-null  int64
#  11  1        494020 non-null  int64
#  12  0.6      494020 non-null  int64
#  13  0.7      494020 non-null  int64
#  14  0.8      494020 non-null  int64
#  15  0.9      494020 non-null  int64
#  16  0.10     494020 non-null  int64
#  17  0.11     494020 non-null  int64
#  18  0.12     494020 non-null  int64
#  19  0.13     494020 non-null  int64
# ...

# %%
 housing.describe()
# Out:
#                    0           181          5450            0.1  \
# count  494020.000000  4.940200e+05  4.940200e+05  494020.000000
# mean       47.979400  3.025616e+03  8.685232e+02       0.000045
# std       707.747185  9.882191e+05  3.304003e+04       0.006673
# min         0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.000000  4.500000e+01  0.000000e+00       0.000000
# 50%         0.000000  5.200000e+02  0.000000e+00       0.000000
# 75%         0.000000  1.032000e+03  0.000000e+00       0.000000
# max     58329.000000  6.933756e+08  5.155468e+06       1.000000
#
#                  0.2            0.3            0.4            0.5  \
# count  494020.000000  494020.000000  494020.000000  494020.000000
# mean        0.006433       0.000014       0.034519       0.000152
# std         0.134805       0.005510       0.782103       0.015520
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
housing.corr()
# Out:
#                 0       181      5450       0.1       0.2       0.3       0.4  \
# 0        1.000000  0.004258  0.005440 -0.000452 -0.003235  0.003786  0.013213
# 181      0.004258  1.000000 -0.000002 -0.000020 -0.000139 -0.000005  0.004483
# 5450     0.005440 -0.000002  1.000000 -0.000175 -0.001254  0.016288  0.004366
# 0.1     -0.000452 -0.000020 -0.000175  1.000000 -0.000318 -0.000017 -0.000295
# 0.2     -0.003235 -0.000139 -0.001254 -0.000318  1.000000 -0.000123 -0.002106
# 0.3      0.003786 -0.000005  0.016288 -0.000017 -0.000123  1.000000  0.000356
# 0.4      0.013213  0.004483  0.004366 -0.000295 -0.002106  0.000356  1.000000
# 0.5      0.005239 -0.000027  0.049330 -0.000065 -0.000467  0.141996  0.008740
# 1       -0.017265  0.001701  0.047814 -0.002784 -0.019908  0.006164  0.105306
# 0.6      0.058095  0.000119  0.023298 -0.000038 -0.000271  0.014285  0.007348
# 0.7      0.021340 -0.000022  0.031680 -0.000070 -0.000504  0.034790  0.024065
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
housing.hist(bins=50, figsize=(20,15))
plt.show()
